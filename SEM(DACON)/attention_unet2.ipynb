# %%
import os 
from cv2 import imread, normalize, resize
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
case_list = ['Case_1', 'Case_2','Case_3','Case_4']
Y_image = []
X_image = []

for case in case_list:
    path = 'C:/Users/user/Desktop/sem/simulation_data/SEM/' +  case # 폴더 경로
    folder_list = ['/80','/81','/82','/83','/84']


    for folder_name in folder_list:
        temp_path = path + folder_name
        os.chdir(temp_path) # 해당 폴더로 이동
        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
        
        for file in files:
            if 'itr0' in file:
                f = imread(file, cv2.IMREAD_GRAYSCALE)
                image = f / 255
                X_image.append(image)
    
    path = 'C:/Users/user/Desktop/sem/simulation_data/Depth/' +  case # 폴더 경로
    for folder_name in folder_list:
        temp_path = path + folder_name
        os.chdir(temp_path) # 해당 폴더로 이동
        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
        
        for file in files:
            f = imread(file, cv2.IMREAD_GRAYSCALE)
            image = f / 255
            Y_image.append(image)

# %%
for case in case_list:
    path = 'C:/Users/user/Desktop/sem/simulation_data/SEM/' +  case # 폴더 경로
    folder_list = ['/80','/81','/82','/83','/84']


    for folder_name in folder_list:
        temp_path = path + folder_name
        os.chdir(temp_path) # 해당 폴더로 이동
        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
        
        for file in files:
            if 'itr1' in file:
                f = imread(file, cv2.IMREAD_GRAYSCALE)
                image = f / 255
                X_image.append(image)
    
    path = 'C:/Users/user/Desktop/sem/simulation_data/Depth/' +  case # 폴더 경로
    for folder_name in folder_list:
        temp_path = path + folder_name
        os.chdir(temp_path) # 해당 폴더로 이동
        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
        
        for file in files:
            f = imread(file, cv2.IMREAD_GRAYSCALE)
            image = f / 255
            Y_image.append(image)

# %%
'''
file_name_list = []
depth_avg_list = []

with open('C:/Users/user/Desktop/sem/train/average_depth.csv', 'r') as file:
    file_read = csv.reader(file)
    for line in file:
        new_line = line.replace("\n", "")
        new_line2 = new_line.split(',')
        file_name_list.append(new_line2[0])	
        depth_avg_list.append(new_line2[1])
        
del file_name_list[0]
del depth_avg_list[0]

depth_list = ['Depth_110', 'Depth_120','Depth_130','Depth_140']

for depht in depth_list:
    path = 'C:/Users/user/Desktop/sem/train/SEM/' +  depht # 폴더 경로
    folder_list = os.listdir(path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음


    for folder_name in folder_list:
        temp_path = path + '/' + folder_name
        os.chdir(temp_path) # 해당 폴더로 이동
        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
        
        temp_y_name = depht.lower() + '_' + folder_name
        
        for file in files:
            f = imread(file, cv2.IMREAD_GRAYSCALE)
            image = f / 255
            X_image.append(image)
            
            avg_depth = float(depth_avg_list[int(file_name_list.index(temp_y_name))])
            Y_image_temp = np.ones(shape=(f.shape[0],f.shape[1]), dtype=np.float64)
            Y_image.append(Y_image_temp * (avg_depth / 255))
'''
# Out:
# '\nfile_name_list = []\ndepth_avg_list = []\n\nwith open(\'C:/Users/user/Desktop/sem/train/average_depth.csv\', \'r\') as file:\n    file_read = csv.reader(file)\n    for line in file:\n        new_line = line.replace("\n", "")\n        new_line2 = new_line.split(\',\')\n        file_name_list.append(new_line2[0])\t\n        depth_avg_list.append(new_line2[1])\n        \ndel file_name_list[0]\ndel depth_avg_list[0]\n\ndepth_list = [\'Depth_110\', \'Depth_120\',\'Depth_130\',\'Depth_140\']\n\nfor depht in depth_list:\n    path = \'C:/Users/user/Desktop/sem/train/SEM/\' +  depht # 폴더 경로\n    folder_list = os.listdir(path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음\n\n\n    for folder_name in folder_list:\n        temp_path = path + \'/\' + folder_name\n        os.chdir(temp_path) # 해당 폴더로 이동\n        files = os.listdir(temp_path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음\n        \n        temp_y_name = depht.lower() + \'_\' + folder_name\n        \n        for file in files:\n            f = imread(file, cv2.IMREAD_GRAYSCALE)\n            image = f / 255\n            X_image.append(image)\n            \n            avg_depth = float(depth_avg_list[int(file_name_list.index(temp_y_name))])\n            Y_image_temp = np.ones(shape=(f.shape[0],f.shape[1]), dtype=np.float64)\n            Y_image.append(Y_image_temp * (avg_depth / 255))\n'

# %%
X_image = np.expand_dims(X_image, axis=-1)
X_image.shape
# Out:
# (173304, 72, 48, 1)

# %%
Y_image = np.expand_dims(Y_image, axis=-1)
Y_image.shape
# Out:
# (173304, 72, 48, 1)

# %%
plt.imshow(X_image[2])
plt.show()

# %%
plt.imshow(Y_image[2])
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(X_image, Y_image, test_size= 0.2)

# %%
x_train = np.array(x_train,dtype=np.float64)
y_train = np.array(y_train,dtype=np.float64)

x_val = np.array(x_val,dtype=np.float64)
y_val = np.array(y_val,dtype=np.float64)


path = 'C:/Users/user/Desktop/sem'
os.chdir(path)

checkpoint_path = "C:/Users/user/Desktop/sem/weight/unet/cp-{epoch:02d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, save_weights_only = True, save_freq='epoch',  monitor='val_loss', verbose=1, mode="min")

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                              patience=8)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.8, verbose=1, mode="min",
                              patience=6, min_lr=0.00001)

# %%
'''
from tensorflow.keras import backend as K

def my_mse(y_true, y_pred):
    #difference between true label and predicted label
    
    if float(y_true[0][0][0]) <= 1:
        mean_sqr_error = K.mean(K.square(y_pred - y_true))
        
    else:
        y_pred_avg= K.mean(y_pred) 
        y_true_avg = float(y_true[0][0][0]) / 255
        mean_sqr_error = K.square(y_true_avg-y_pred_avg)
        
    return mean_sqr_error

'''
# Out:
# '\nfrom tensorflow.keras import backend as K\n\ndef my_mse(y_true, y_pred):\n    #difference between true label and predicted label\n    \n    if float(y_true[0][0][0]) <= 1:\n        mean_sqr_error = K.mean(K.square(y_pred - y_true))\n        \n    else:\n        y_pred_avg= K.mean(y_pred) \n        y_true_avg = float(y_true[0][0][0]) / 255\n        mean_sqr_error = K.square(y_true_avg-y_pred_avg)\n        \n    return mean_sqr_error\n\n'

# %%
from keras_unet_collection import models
from tensorflow.keras.layers import LeakyReLU

model = models.att_unet_2d((f.shape[0],f.shape[1],1), [64, 128, 256, 512], n_labels= 1, output_activation=None, batch_norm=True, activation='LeakyReLU', )

model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=1 * 1e-4))
history = model.fit(x_train, y_train, 
                         validation_data=(x_val, y_val),
                         epochs=80, batch_size = 32,
                         callbacks= [ earlystopping, reduce_lr, cp_callback])
# Out:
# Epoch 1/80
# 4333/4333 [==============================] - 800s 183ms/step - loss: 0.0046 - val_loss: 5.1515e-04
#
# Epoch 00001: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-01.ckpt
# Epoch 2/80
# 4333/4333 [==============================] - 780s 180ms/step - loss: 3.9019e-04 - val_loss: 7.6671e-04
#
# Epoch 00002: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-02.ckpt
# Epoch 3/80
# 4333/4333 [==============================] - 791s 182ms/step - loss: 2.9480e-04 - val_loss: 2.8971e-04
#
# Epoch 00003: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-03.ckpt
# Epoch 4/80
# 4333/4333 [==============================] - 819s 189ms/step - loss: 2.2373e-04 - val_loss: 2.0217e-04
#
# Epoch 00004: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-04.ckpt
# Epoch 5/80
# 4333/4333 [==============================] - 825s 190ms/step - loss: 1.8148e-04 - val_loss: 1.6139e-04
#
# Epoch 00005: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-05.ckpt
# Epoch 6/80
# 4333/4333 [==============================] - 827s 191ms/step - loss: 1.5778e-04 - val_loss: 1.5407e-04
#
# Epoch 00006: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-06.ckpt
# Epoch 7/80
# 4333/4333 [==============================] - 818s 189ms/step - loss: 1.4243e-04 - val_loss: 2.0653e-04
#
# Epoch 00007: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-07.ckpt
# Epoch 8/80
# 4333/4333 [==============================] - 804s 186ms/step - loss: 1.2900e-04 - val_loss: 1.2404e-04
#
# Epoch 00008: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-08.ckpt
# Epoch 9/80
# 4333/4333 [==============================] - 813s 188ms/step - loss: 1.2065e-04 - val_loss: 1.1910e-04
#
# Epoch 00009: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-09.ckpt
# Epoch 10/80
# 4333/4333 [==============================] - 1089s 251ms/step - loss: 1.1421e-04 - val_loss: 1.0744e-04
#
# Epoch 00010: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-10.ckpt
# Epoch 11/80
# 4333/4333 [==============================] - 1023s 236ms/step - loss: 1.0759e-04 - val_loss: 1.1909e-04
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
#
# Epoch 00011: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-11.ckpt
# Epoch 12/80
# 4333/4333 [==============================] - 821s 189ms/step - loss: 9.5346e-05 - val_loss: 1.0933e-04
#
# Epoch 00012: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-12.ckpt
# Epoch 13/80
# 4333/4333 [==============================] - 814s 188ms/step - loss: 9.2023e-05 - val_loss: 1.0157e-04
#
# Epoch 00013: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-13.ckpt
# Epoch 14/80
# 4333/4333 [==============================] - 3155s 728ms/step - loss: 8.9598e-05 - val_loss: 8.9400e-05
#
# Epoch 00014: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-14.ckpt
# Epoch 15/80
# 4333/4333 [==============================] - 2387s 551ms/step - loss: 8.5733e-05 - val_loss: 8.1823e-05
#
# Epoch 00015: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-15.ckpt
# Epoch 16/80
# 4333/4333 [==============================] - 821s 189ms/step - loss: 8.2539e-05 - val_loss: 8.2725e-05
#
# Epoch 00016: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-16.ckpt
# Epoch 17/80
# 4333/4333 [==============================] - 811s 187ms/step - loss: 7.8610e-05 - val_loss: 9.9996e-05
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
#
# Epoch 00017: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-17.ckpt
# Epoch 18/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 7.3029e-05 - val_loss: 1.1461e-04
#
# Epoch 00018: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-18.ckpt
# Epoch 19/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 7.0277e-05 - val_loss: 7.7583e-05
#
# Epoch 00019: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-19.ckpt
# Epoch 20/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 6.8191e-05 - val_loss: 7.7331e-05
#
# Epoch 00020: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-20.ckpt
# Epoch 21/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 6.5987e-05 - val_loss: 8.6407e-05
#
# Epoch 00021: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-21.ckpt
# Epoch 22/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 6.5917e-05 - val_loss: 8.0784e-05
#
# Epoch 00022: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-22.ckpt
# Epoch 23/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 6.3460e-05 - val_loss: 7.7705e-05
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00023: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-23.ckpt
# Epoch 24/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 5.8780e-05 - val_loss: 7.8522e-05
#
# Epoch 00024: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-24.ckpt
# Epoch 25/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 5.7255e-05 - val_loss: 6.1379e-05
#
# Epoch 00025: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-25.ckpt
# Epoch 26/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 5.6023e-05 - val_loss: 6.6411e-05
#
# Epoch 00026: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-26.ckpt
# Epoch 27/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 5.5862e-05 - val_loss: 7.3381e-05
#
# Epoch 00027: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-27.ckpt
# Epoch 28/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 5.4159e-05 - val_loss: 8.8943e-05
#
# Epoch 00028: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-28.ckpt
# Epoch 29/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 5.3311e-05 - val_loss: 6.0253e-05
#
# Epoch 00029: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-29.ckpt
# Epoch 30/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 5.2278e-05 - val_loss: 6.2028e-05
#
# Epoch 00030: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-30.ckpt
# Epoch 31/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 5.1980e-05 - val_loss: 6.2142e-05
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 4.0960000478662555e-05.
#
# Epoch 00031: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-31.ckpt
# Epoch 32/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.9828e-05 - val_loss: 6.0484e-05
#
# Epoch 00032: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-32.ckpt
# Epoch 33/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.8366e-05 - val_loss: 5.9215e-05
#
# Epoch 00033: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-33.ckpt
# Epoch 34/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.8330e-05 - val_loss: 6.2550e-05
#
# Epoch 00034: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-34.ckpt
# Epoch 35/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.7720e-05 - val_loss: 5.8759e-05
#
# Epoch 00035: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-35.ckpt
# Epoch 36/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.6869e-05 - val_loss: 5.8887e-05
#
# Epoch 00036: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-36.ckpt
# Epoch 37/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.6075e-05 - val_loss: 6.0892e-05
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.2767999800853435e-05.
#
# Epoch 00037: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-37.ckpt
# Epoch 38/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.4676e-05 - val_loss: 5.8147e-05
#
# Epoch 00038: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-38.ckpt
# Epoch 39/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.3781e-05 - val_loss: 5.7595e-05
#
# Epoch 00039: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-39.ckpt
# Epoch 40/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.3222e-05 - val_loss: 5.9113e-05
#
# Epoch 00040: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-40.ckpt
# Epoch 41/80
# 4333/4333 [==============================] - 805s 186ms/step - loss: 4.3425e-05 - val_loss: 5.5766e-05
#
# Epoch 00041: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-41.ckpt
# Epoch 42/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.3190e-05 - val_loss: 5.7285e-05
#
# Epoch 00042: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-42.ckpt
# Epoch 43/80
# 4333/4333 [==============================] - 807s 186ms/step - loss: 4.2864e-05 - val_loss: 5.7521e-05
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 2.6214399258606137e-05.
#
# Epoch 00043: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-43.ckpt
# Epoch 44/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.1210e-05 - val_loss: 5.3527e-05
#
# Epoch 00044: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-44.ckpt
# Epoch 45/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.0914e-05 - val_loss: 5.4166e-05
#
# Epoch 00045: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-45.ckpt
# Epoch 46/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.0669e-05 - val_loss: 5.4373e-05
#
# Epoch 00046: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-46.ckpt
# Epoch 47/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.0855e-05 - val_loss: 5.3611e-05
#
# Epoch 00047: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-47.ckpt
# Epoch 48/80
# 4333/4333 [==============================] - 807s 186ms/step - loss: 4.0045e-05 - val_loss: 5.3798e-05
#
# Epoch 00048: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-48.ckpt
# Epoch 49/80
# 4333/4333 [==============================] - 806s 186ms/step - loss: 4.0255e-05 - val_loss: 5.2773e-05
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.09715188248083e-05.
#
# Epoch 00049: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-49.ckpt
# Epoch 50/80
# 4333/4333 [==============================] - 807s 186ms/step - loss: 3.9057e-05 - val_loss: 5.2938e-05
#
# Epoch 00050: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-50.ckpt
# Epoch 51/80
# 4333/4333 [==============================] - 825s 190ms/step - loss: 3.8850e-05 - val_loss: 5.2626e-05
#
# Epoch 00051: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-51.ckpt
# Epoch 52/80
# 4333/4333 [==============================] - 818s 189ms/step - loss: 3.9349e-05 - val_loss: 5.1719e-05
#
# Epoch 00052: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-52.ckpt
# Epoch 53/80
# 4333/4333 [==============================] - 840s 194ms/step - loss: 3.8419e-05 - val_loss: 5.2329e-05
#
# Epoch 00053: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-53.ckpt
# Epoch 54/80
# 4333/4333 [==============================] - 811s 187ms/step - loss: 3.8287e-05 - val_loss: 5.1555e-05
#
# Epoch 00054: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-54.ckpt
# Epoch 55/80
# 4333/4333 [==============================] - 804s 186ms/step - loss: 3.8155e-05 - val_loss: 5.2905e-05
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.6777214477770033e-05.
#
# Epoch 00055: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-55.ckpt
# Epoch 56/80
# 4333/4333 [==============================] - 803s 185ms/step - loss: 3.7474e-05 - val_loss: 5.2412e-05
#
# Epoch 00056: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-56.ckpt
# Epoch 57/80
# 4333/4333 [==============================] - 798s 184ms/step - loss: 3.7509e-05 - val_loss: 5.1788e-05
#
# Epoch 00057: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-57.ckpt
# Epoch 58/80
# 4333/4333 [==============================] - 807s 186ms/step - loss: 3.7748e-05 - val_loss: 5.1719e-05
#
# Epoch 00058: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-58.ckpt
# Epoch 59/80
# 4333/4333 [==============================] - 817s 189ms/step - loss: 3.7523e-05 - val_loss: 6.1172e-05
#
# Epoch 00059: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-59.ckpt
# Epoch 60/80
# 4333/4333 [==============================] - 797s 184ms/step - loss: 3.7084e-05 - val_loss: 5.3398e-05
#
# Epoch 00060: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-60.ckpt
# Epoch 61/80
# 4333/4333 [==============================] - 791s 183ms/step - loss: 3.6756e-05 - val_loss: 5.2417e-05
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.3421771291177721e-05.
#
# Epoch 00061: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-61.ckpt
# Epoch 62/80
# 4333/4333 [==============================] - 794s 183ms/step - loss: 3.6761e-05 - val_loss: 5.0842e-05
#
# Epoch 00062: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-62.ckpt
# Epoch 63/80
# 4333/4333 [==============================] - 800s 185ms/step - loss: 3.6334e-05 - val_loss: 5.1108e-05
#
# Epoch 00063: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-63.ckpt
# Epoch 64/80
# 4333/4333 [==============================] - 800s 185ms/step - loss: 3.6313e-05 - val_loss: 5.1738e-05
#
# Epoch 00064: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-64.ckpt
# Epoch 65/80
# 4333/4333 [==============================] - 817s 189ms/step - loss: 3.6192e-05 - val_loss: 6.8173e-05
#
# Epoch 00065: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-65.ckpt
# Epoch 66/80
# 4333/4333 [==============================] - 814s 188ms/step - loss: 3.5898e-05 - val_loss: 5.1828e-05
#
# Epoch 00066: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-66.ckpt
# Epoch 67/80
# 4333/4333 [==============================] - 808s 186ms/step - loss: 3.5990e-05 - val_loss: 5.0916e-05
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.0737417323980481e-05.
#
# Epoch 00067: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-67.ckpt
# Epoch 68/80
# 4333/4333 [==============================] - 792s 183ms/step - loss: 3.5438e-05 - val_loss: 5.1151e-05
#
# Epoch 00068: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-68.ckpt
# Epoch 69/80
# 4333/4333 [==============================] - 784s 181ms/step - loss: 3.5149e-05 - val_loss: 5.1403e-05
#
# Epoch 00069: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-69.ckpt
# Epoch 70/80
# 4333/4333 [==============================] - 781s 180ms/step - loss: 3.5356e-05 - val_loss: 5.0664e-05
#
# Epoch 00070: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-70.ckpt
# Epoch 71/80
# 4333/4333 [==============================] - 765s 177ms/step - loss: 3.5166e-05 - val_loss: 5.7469e-05
#
# Epoch 00071: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-71.ckpt
# Epoch 72/80
# 4333/4333 [==============================] - 800s 185ms/step - loss: 3.4975e-05 - val_loss: 5.0776e-05
#
# Epoch 00072: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-72.ckpt
# Epoch 73/80
# 4333/4333 [==============================] - 821s 190ms/step - loss: 3.5579e-05 - val_loss: 5.1021e-05
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00073: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-73.ckpt
# Epoch 74/80
# 4333/4333 [==============================] - 841s 194ms/step - loss: 3.4801e-05 - val_loss: 5.1672e-05
#
# Epoch 00074: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-74.ckpt
# Epoch 75/80
# 4333/4333 [==============================] - 845s 195ms/step - loss: 3.4716e-05 - val_loss: 5.0722e-05
#
# Epoch 00075: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-75.ckpt
# Epoch 76/80
# 4333/4333 [==============================] - 833s 192ms/step - loss: 3.4895e-05 - val_loss: 7.0963e-05
#
# Epoch 00076: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-76.ckpt
# Epoch 77/80
# 4333/4333 [==============================] - 835s 193ms/step - loss: 3.4370e-05 - val_loss: 5.1813e-05
#
# Epoch 00077: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-77.ckpt
# Epoch 78/80
# 4333/4333 [==============================] - 802s 185ms/step - loss: 3.4629e-05 - val_loss: 5.0190e-05
#
# Epoch 00078: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-78.ckpt
# Epoch 79/80
# 4333/4333 [==============================] - 825s 190ms/step - loss: 3.4506e-05 - val_loss: 5.0367e-05
#
# Epoch 00079: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-79.ckpt
# Epoch 80/80
# 4333/4333 [==============================] - 829s 191ms/step - loss: 3.4260e-05 - val_loss: 5.0108e-05
#
# Epoch 00080: saving model to C:/Users/user/Desktop/sem/weight/unet\cp-80.ckpt

# %%
def plot_model__hist(hist):
    plt.figure(figsize=(6,6))
    #plt.style.use("ggplot")
    plt.plot(hist.history['loss'], color='b', label="Training loss")
    plt.plot(hist.history['val_loss'], color='r', label="Validation loss")
    plt.legend()
    plt.show()

# %%
model = models.att_unet_2d((f.shape[0],f.shape[1],1), [64, 128, 256, 512], n_labels= 1, output_activation=None, batch_norm=True)
val_loss_history = history.history["val_loss"]
max_point = val_loss_history.index(min(val_loss_history))


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1 * 1e-4),
        loss='MSE',
        metrics=['mse'])

if max_point > 8:
    model.load_weights(
        "C:/Users/user/Desktop/sem/weight/unet/cp-" + str(max_point+1) + ".ckpt"
    )
else:
    model.load_weights(
        "C:/Users/user/Desktop/sem/weight/unet/cp-0" + str(max_point+1) + ".ckpt"
    )

# %%
max_point
# Out:
# 79

# %%
score = model.evaluate(x_val, y_val)

plot_model__hist(history)
# Out:
# 1084/1084 [==============================] - 62s 57ms/step - loss: 0.0172 - mse: 0.0172

# %%
decoded_images = model.predict(x_val)

# %%
distance_gap = decoded_images*255 - y_val*255
distance_gap_new = distance_gap.reshape(y_val.shape[0],-1)

avg_depth = np.mean(distance_gap_new,axis=1)

# %%
np.mean(avg_depth)
# Out:
# -20.12919279828189

# %%
plt.hist(avg_depth)

plt.show()

# %%
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(y_val[i]*255, cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Original Images')
plt.show()

fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(decoded_images[i]*255, cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Auto Encoder Images')
plt.show()

# %%
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow((y_val[i]*255 - decoded_images[i]*255), cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Original Images')
plt.show()

# %%
path = 'C:/Users/user/Desktop/sem/test/SEM' # 폴더 경로

test_image = []


os.chdir(path) # 해당 폴더로 이동
files = os.listdir(path) # 해당 폴더에 있는 파일 이름을 리스트 형태로 받음
    
for file in files:
    f = imread(file, cv2.IMREAD_GRAYSCALE)
    image = f / 255
    test_image.append(image)

# %%
test_image = np.expand_dims(test_image, axis=-1)

# %%
decoded_images = model.predict(np.array(test_image, dtype=np.float64))

# %%
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(test_image[i]*255, cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('SEM Images')
plt.show()

fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(decoded_images[i]*255, cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Auto Encoder Images')
plt.show()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
import zipfile
def inference(decoded_images, files):
        
    os.makedirs('../../submission', exist_ok=True)
    os.chdir("../../submission")
    sub_imgs = []
    
    for path, pred_img in zip(files, decoded_images):
        cv2.imwrite(path, pred_img*255)
        sub_imgs.append(path)
        
    submission = zipfile.ZipFile("../submission.zip", 'w')
    for path in sub_imgs:
        submission.write(path)
    submission.close()
    
inference(decoded_images, files)

# %%
grayImg = cv2.imread('C:/Users/user/Desktop/sem/submission/000000.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(grayImg)
plt.show()

# %%
plt.imshow(decoded_images[0])
plt.show()

# %%
model.summary()
# Out:
# Model: "attunet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 72, 48, 1)]  0
# __________________________________________________________________________________________________
# attunet_down0_0 (Conv2D)        (None, 72, 48, 64)   576         input_5[0][0]
# __________________________________________________________________________________________________
# attunet_down0_0_bn (BatchNormal (None, 72, 48, 64)   256         attunet_down0_0[0][0]
# __________________________________________________________________________________________________
# attunet_down0_0_activation (ReL (None, 72, 48, 64)   0           attunet_down0_0_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down0_1 (Conv2D)        (None, 72, 48, 64)   36864       attunet_down0_0_activation[0][0]
# __________________________________________________________________________________________________
# attunet_down0_1_bn (BatchNormal (None, 72, 48, 64)   256         attunet_down0_1[0][0]
# __________________________________________________________________________________________________
# attunet_down0_1_activation (ReL (None, 72, 48, 64)   0           attunet_down0_1_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down1_encode_maxpool (M (None, 36, 24, 64)   0           attunet_down0_1_activation[0][0]
# __________________________________________________________________________________________________
# attunet_down1_conv_0 (Conv2D)   (None, 36, 24, 128)  73728       attunet_down1_encode_maxpool[0][0
# __________________________________________________________________________________________________
# attunet_down1_conv_0_bn (BatchN (None, 36, 24, 128)  512         attunet_down1_conv_0[0][0]
# __________________________________________________________________________________________________
# attunet_down1_conv_0_activation (None, 36, 24, 128)  0           attunet_down1_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down1_conv_1 (Conv2D)   (None, 36, 24, 128)  147456      attunet_down1_conv_0_activation[0
# __________________________________________________________________________________________________
# attunet_down1_conv_1_bn (BatchN (None, 36, 24, 128)  512         attunet_down1_conv_1[0][0]
# __________________________________________________________________________________________________
# attunet_down1_conv_1_activation (None, 36, 24, 128)  0           attunet_down1_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down2_encode_maxpool (M (None, 18, 12, 128)  0           attunet_down1_conv_1_activation[0
# __________________________________________________________________________________________________
# attunet_down2_conv_0 (Conv2D)   (None, 18, 12, 256)  294912      attunet_down2_encode_maxpool[0][0
# __________________________________________________________________________________________________
# attunet_down2_conv_0_bn (BatchN (None, 18, 12, 256)  1024        attunet_down2_conv_0[0][0]
# __________________________________________________________________________________________________
# attunet_down2_conv_0_activation (None, 18, 12, 256)  0           attunet_down2_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down2_conv_1 (Conv2D)   (None, 18, 12, 256)  589824      attunet_down2_conv_0_activation[0
# __________________________________________________________________________________________________
# attunet_down2_conv_1_bn (BatchN (None, 18, 12, 256)  1024        attunet_down2_conv_1[0][0]
# __________________________________________________________________________________________________
# attunet_down2_conv_1_activation (None, 18, 12, 256)  0           attunet_down2_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down3_encode_maxpool (M (None, 9, 6, 256)    0           attunet_down2_conv_1_activation[0
# __________________________________________________________________________________________________
# attunet_down3_conv_0 (Conv2D)   (None, 9, 6, 512)    1179648     attunet_down3_encode_maxpool[0][0
# __________________________________________________________________________________________________
# attunet_down3_conv_0_bn (BatchN (None, 9, 6, 512)    2048        attunet_down3_conv_0[0][0]
# __________________________________________________________________________________________________
# attunet_down3_conv_0_activation (None, 9, 6, 512)    0           attunet_down3_conv_0_bn[0][0]
# __________________________________________________________________________________________________
# attunet_down3_conv_1 (Conv2D)   (None, 9, 6, 512)    2359296     attunet_down3_conv_0_activation[0
# __________________________________________________________________________________________________
# attunet_down3_conv_1_bn (BatchN (None, 9, 6, 512)    2048        attunet_down3_conv_1[0][0]
# __________________________________________________________________________________________________
# attunet_down3_conv_1_activation (None, 9, 6, 512)    0           attunet_down3_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# attunet_up0_decode_unpool (UpSa (None, 18, 12, 512)  0           attunet_down3_conv_1_activation[0
# __________________________________________________________________________________________________
# attunet_up0_att_theta_x (Conv2D (None, 18, 12, 128)  32896       attunet_down2_conv_1_activation[0
# __________________________________________________________________________________________________
# attunet_up0_att_phi_g (Conv2D)  (None, 18, 12, 128)  65664       attunet_up0_decode_unpool[0][0]
# __________________________________________________________________________________________________
# attunet_up0_att_add (Add)       (None, 18, 12, 128)  0           attunet_up0_att_theta_x[0][0]
#                                                                  attunet_up0_att_phi_g[0][0]
# __________________________________________________________________________________________________
# attunet_up0_att_activation (ReL (None, 18, 12, 128)  0           attunet_up0_att_add[0][0]
# __________________________________________________________________________________________________
# attunet_up0_att_psi_f (Conv2D)  (None, 18, 12, 1)    129         attunet_up0_att_activation[0][0]
# __________________________________________________________________________________________________
# attunet_up0_att_sigmoid (Activa (None, 18, 12, 1)    0           attunet_up0_att_psi_f[0][0]
# __________________________________________________________________________________________________
# attunet_up0_att_masking (Multip (None, 18, 12, 256)  0           attunet_down2_conv_1_activation[0
#                                                                  attunet_up0_att_sigmoid[0][0]
# __________________________________________________________________________________________________
# attunet_up0_concat (Concatenate (None, 18, 12, 768)  0           attunet_up0_decode_unpool[0][0]
#                                                                  attunet_up0_att_masking[0][0]
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_0 (None, 18, 12, 256)  1769472     attunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_0 (None, 18, 12, 256)  1024        attunet_up0_conv_after_concat_0[0
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_0 (None, 18, 12, 256)  0           attunet_up0_conv_after_concat_0_b
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_1 (None, 18, 12, 256)  589824      attunet_up0_conv_after_concat_0_a
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_1 (None, 18, 12, 256)  1024        attunet_up0_conv_after_concat_1[0
# __________________________________________________________________________________________________
# attunet_up0_conv_after_concat_1 (None, 18, 12, 256)  0           attunet_up0_conv_after_concat_1_b
# __________________________________________________________________________________________________
# attunet_up1_decode_unpool (UpSa (None, 36, 24, 256)  0           attunet_up0_conv_after_concat_1_a
# __________________________________________________________________________________________________
# attunet_up1_att_theta_x (Conv2D (None, 36, 24, 64)   8256        attunet_down1_conv_1_activation[0
# __________________________________________________________________________________________________
# attunet_up1_att_phi_g (Conv2D)  (None, 36, 24, 64)   16448       attunet_up1_decode_unpool[0][0]
# __________________________________________________________________________________________________
# attunet_up1_att_add (Add)       (None, 36, 24, 64)   0           attunet_up1_att_theta_x[0][0]
#                                                                  attunet_up1_att_phi_g[0][0]
# __________________________________________________________________________________________________
# attunet_up1_att_activation (ReL (None, 36, 24, 64)   0           attunet_up1_att_add[0][0]
# __________________________________________________________________________________________________
# attunet_up1_att_psi_f (Conv2D)  (None, 36, 24, 1)    65          attunet_up1_att_activation[0][0]
# __________________________________________________________________________________________________
# attunet_up1_att_sigmoid (Activa (None, 36, 24, 1)    0           attunet_up1_att_psi_f[0][0]
# __________________________________________________________________________________________________
# attunet_up1_att_masking (Multip (None, 36, 24, 128)  0           attunet_down1_conv_1_activation[0
#                                                                  attunet_up1_att_sigmoid[0][0]
# __________________________________________________________________________________________________
# attunet_up1_concat (Concatenate (None, 36, 24, 384)  0           attunet_up1_decode_unpool[0][0]
#                                                                  attunet_up1_att_masking[0][0]
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_0 (None, 36, 24, 128)  442368      attunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_0 (None, 36, 24, 128)  512         attunet_up1_conv_after_concat_0[0
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_0 (None, 36, 24, 128)  0           attunet_up1_conv_after_concat_0_b
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_1 (None, 36, 24, 128)  147456      attunet_up1_conv_after_concat_0_a
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_1 (None, 36, 24, 128)  512         attunet_up1_conv_after_concat_1[0
# __________________________________________________________________________________________________
# attunet_up1_conv_after_concat_1 (None, 36, 24, 128)  0           attunet_up1_conv_after_concat_1_b
# __________________________________________________________________________________________________
# attunet_up2_decode_unpool (UpSa (None, 72, 48, 128)  0           attunet_up1_conv_after_concat_1_a
# __________________________________________________________________________________________________
# attunet_up2_att_theta_x (Conv2D (None, 72, 48, 32)   2080        attunet_down0_1_activation[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_phi_g (Conv2D)  (None, 72, 48, 32)   4128        attunet_up2_decode_unpool[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_add (Add)       (None, 72, 48, 32)   0           attunet_up2_att_theta_x[0][0]
#                                                                  attunet_up2_att_phi_g[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_activation (ReL (None, 72, 48, 32)   0           attunet_up2_att_add[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_psi_f (Conv2D)  (None, 72, 48, 1)    33          attunet_up2_att_activation[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_sigmoid (Activa (None, 72, 48, 1)    0           attunet_up2_att_psi_f[0][0]
# __________________________________________________________________________________________________
# attunet_up2_att_masking (Multip (None, 72, 48, 64)   0           attunet_down0_1_activation[0][0]
#                                                                  attunet_up2_att_sigmoid[0][0]
# __________________________________________________________________________________________________
# attunet_up2_concat (Concatenate (None, 72, 48, 192)  0           attunet_up2_decode_unpool[0][0]
#                                                                  attunet_up2_att_masking[0][0]
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_0 (None, 72, 48, 64)   110592      attunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_0 (None, 72, 48, 64)   256         attunet_up2_conv_after_concat_0[0
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_0 (None, 72, 48, 64)   0           attunet_up2_conv_after_concat_0_b
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_1 (None, 72, 48, 64)   36864       attunet_up2_conv_after_concat_0_a
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_1 (None, 72, 48, 64)   256         attunet_up2_conv_after_concat_1[0
# __________________________________________________________________________________________________
# attunet_up2_conv_after_concat_1 (None, 72, 48, 64)   0           attunet_up2_conv_after_concat_1_b
# __________________________________________________________________________________________________
# attunet_output (Conv2D)         (None, 72, 48, 1)    65          attunet_up2_conv_after_concat_1_a
# ==================================================================================================
# Total params: 7,919,908
# Trainable params: 7,914,276
# Non-trainable params: 5,632
# __________________________________________________________________________________________________
